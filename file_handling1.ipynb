# %%
RAMA GALE
AMB2208

# %%
file=open("abc.txt", "r")
content=file.read()
print(content)
file.close()
# Out:
# hello world

# %%
file=open("abc.txt", "w")
file.write("hello world")
file.close()

# %%
report=open("abc.txt",'r')
content=report.read()
print(content)
report.close()
# Out:
# hello world

# %%
file=open("abc.txt","a")
file.write("how r u")
file.close()

# %%
file=open("abc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello worldhi universehi universehi universehi universehi universehi universehi universehow r uhow r uhow r uhow r uhow r uhow r uhow r uhow r uhow r u

# %%
file=open("jk.txt","w")
file.write("hi mom")
file.close()

# %%
file=open("jk.txt","a")
file.write("\n how are you")
file.close()

# %%
file=open("jk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hi mom
#  how are you
#  how are you

# %%
with open("jk.txt","r") as file:
    print(file.read())
# Out:
# hi mom
#  how are you
#  how are you

# %%
with open("jk.txt","a") as file:
  file.write("iam fine")

# %%
with open("jk.txt","r") as file:
  print(file.readlines())
# Out:
# ['iam fineiam fine']

# %%
#exception file handling
try:
  file=open("kd.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found")
# Out:
# file not found

# %%
try:
  with open("kd.txt","r") as file:
    print(file.read())

except:
  print("file not found")
# Out:
# file not found

# %%
try:
  a=2
  b=3
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def fum(a,b):
  try:
    c=a/b
  except ZeroDivisionError:
      print("divisible by zero")
  except NameError:
      print("varible not declared")
  except:
      print("some error occured")
  else:
      print("executed without error")
      print("value of c:",c)
  finally:print("end of program")
a=6
b=3
fum(a,b)
# Out:
# executed without error
# value of c: 2.0
# end of program
